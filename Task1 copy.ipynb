# %% [markdown]
# ##  My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __ARSALAN RASHID__
#
# IAM CURRENTLY WORKING AS DATA ANALYTIC AND SEO EXPERT AND MY DESIRED OCCUPATION IS TO BE DATA SCIENTIST

# %% [markdown]
# _I am interested in Data Science because I would love to contribute towards affordable and quality healthcare in the future_

# %% [markdown]
# ###  The below should print ‘Hello World’

# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %% [markdown]
# -  one
# -  two
# -  three
# -  four
# -  five

# %% [markdown]
# 1. arsalan
# 1. faizan
# 1. inan
# 1. mustafa

# %% [markdown]
# ***
